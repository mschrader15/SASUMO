# %%
import numpy as np

# %%
data = []
with open('/Users/max/tmp/CarFollowingNormalSaltelli/07.28.2022_08.37.49/SALib_Samples.txt', "r") as f:
    data.extend(list(map(float, line.split(" "))) for line in f.readlines())

# %%
data = np.array(data)

# %%
import plotly.graph_objects as go


go.Figure(data=[go.Histogram(x=data[:, 3])])

# %%
import plotly.graph_objects as go




fig = go.Figure()
fig.add_trace(
    go.Histogram2d(
        x=data[:, 1],
        y=data[:, 3],
        # z=results_df["timeloss_ratio"],
        histfunc="count",
        xbins_size=0.25,
        ybins_size=0.25,
    )
)
